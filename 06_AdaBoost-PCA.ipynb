# %%
import pandas as pd

url = "https://huggingface.co/datasets/chuso6/har_features/resolve/main/har_features.csv"

df_final_features = pd.read_csv(url)
df_final_features.head()
# Out:
#    activity  subject  window_id  T_acc_mean_x  T_acc_mean_y  T_acc_mean_z  \
# 0         1        1          0      8.015509      1.058076      5.553903
# 1         1        1          1      7.920071      1.126935      5.683707
# 2         1        1          2      8.001183      1.141395      5.559029
# 3         1        1          3      7.941989      1.143843      5.658659
# 4         1        1          4      7.996011      1.138048      5.567233
#
#    T_acc_std_x  T_acc_std_y  T_acc_std_z  T_acc_max_x  ...  LL_mag_max_x  \
# 0     0.129444     0.039797     0.191729       8.1605  ...       0.74182
# 1     0.058170     0.026639     0.105984       8.0412  ...       0.74320
# 2     0.095242     0.030720     0.148445       8.1763  ...       0.74335
# 3     0.059360     0.024328     0.094272       8.1160  ...       0.74302
# 4     0.042821     0.021047     0.067826       8.0860  ...       0.74316
#
#    LL_mag_max_y  LL_mag_max_z  LL_mag_corr_xy  LL_mag_corr_xz  LL_mag_corr_yz  \
# 0       0.30267     -0.055365       -0.380922        0.214412       -0.094971
# 1       0.30342     -0.054963       -0.351583        0.448888       -0.306916
# 2       0.30377     -0.054945       -0.231525        0.377849       -0.342104
# 3       0.30397     -0.054711       -0.266598        0.365792       -0.255355
# 4       0.30423     -0.055413       -0.169517        0.621999       -0.270246
#
#    LL_mag_mag_mean  LL_mag_mag_std  LL_mag_mag_auc  LL_mag_mag_mean_diff
# 0         0.800508        0.000745        2.369513              0.000941
# 1         0.801040        0.000701        2.371086              0.000761
# 2         0.801930        0.000862        2.373707              0.000829
# 3         0.802269        0.000731        2.374725              0.000797
# 4         0.802356        0.000820        2.375000              0.000938
#
# [5 rows x 243 columns]

# %%
print(df_final_features.columns)
# Out:
# Index(['activity', 'subject', 'window_id', 'T_acc_mean_x', 'T_acc_mean_y',
#        'T_acc_mean_z', 'T_acc_std_x', 'T_acc_std_y', 'T_acc_std_z',
#        'T_acc_max_x',
#        ...
#        'LL_mag_max_x', 'LL_mag_max_y', 'LL_mag_max_z', 'LL_mag_corr_xy',
#        'LL_mag_corr_xz', 'LL_mag_corr_yz', 'LL_mag_mag_mean', 'LL_mag_mag_std',
#        'LL_mag_mag_auc', 'LL_mag_mag_mean_diff'],
#       dtype='object', length=243)

# %% [markdown]
# ##Nuevo AdaBoost

# %%
import numpy as np
import pandas as pd
import time

from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import LeaveOneGroupOut, GroupKFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA, PCA
from sklearn.feature_selection import SelectFromModel

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)

# =========================================================
# GRIDS DE HIPERPARÁMETROS
# =========================================================

GRID_KPCA = [
    {
        'reduccion__kernel': ['rbf'],
        'reduccion__n_components': [32, 64, 128],
        'reduccion__gamma': [0.001, 0.01, 0.1, 'scale']
    },
    {
        'reduccion__kernel': ['poly'],
        'reduccion__n_components': [32, 64],
        'reduccion__degree': [2, 3],
        'reduccion__gamma': ['scale']
    }
]

GRID_ADABOOST = {
    'modelo__learning_rate': [0.001, 0.01, 0.1, 0.5, 1.0, 2.0],
    'modelo__n_estimators': [25, 50, 100]
}

# =========================================================
# NESTED LOSO — ADABOOST
# =========================================================

def nested_loso_adaboost(
    datos,
    nombre_reduccion,          # 'pca' | 'kpca' | 'bosque' | 'sin'
    target_col="activity",
    group_col="subject",
    scoring="accuracy",
    average="weighted",
    random_state=42
):
    print(f"--- NESTED LOSO | Modelo: ADABOOST | Reducción: {nombre_reduccion.upper()} ---")

    X = datos.drop(columns=[target_col, group_col])
    y = datos[target_col]
    groups = datos[group_col]

    logo_outer = LeaveOneGroupOut()
    fold = 1

    accuracies, precisions, recalls, f1_scores = [], [], [], []
    start_time_total = time.time()

    for train_index, test_index in logo_outer.split(X, y, groups):
        start_time_fold = time.time()

        X_test      = X.iloc[test_index]
        y_test      = y.iloc[test_index]
        sujeto_eval = groups.iloc[test_index].unique()[0]

        X_train_val      = X.iloc[train_index]
        y_train_val      = y.iloc[train_index]
        groups_train_val = groups.iloc[train_index]

        # =====================================================
        # 1. PIPELINE + GRID SEGÚN REDUCCIÓN
        # =====================================================

        pasos = [('scaler', StandardScaler())]

        if nombre_reduccion == 'pca':
            pasos.append(('reduccion', PCA(n_components=0.95, random_state=random_state)))
            param_grid_red = {}

        elif nombre_reduccion == 'kpca':
            pasos.append(('reduccion', KernelPCA(random_state=random_state, n_jobs=-1)))
            param_grid_red = GRID_KPCA

        elif nombre_reduccion == 'bosque':
            selector = RandomForestClassifier(n_estimators=100, random_state=random_state, n_jobs=-1)
            pasos.append(('reduccion', SelectFromModel(selector)))
            param_grid_red = {}

        elif nombre_reduccion == 'sin':
            param_grid_red = {}

        else:
            raise ValueError(f"Reducción '{nombre_reduccion}' no implementada.")

        pasos.append((
            'modelo',
            AdaBoostClassifier(
                estimator=DecisionTreeClassifier(max_depth=1),
                random_state=random_state
            )
        ))

        pipeline = Pipeline(pasos)

        # =====================================================
        # 2. COMBINAR GRIDS
        # =====================================================

        if isinstance(param_grid_red, list):
            param_grid = [{**bloque, **GRID_ADABOOST} for bloque in param_grid_red]
        else:
            param_grid = {**param_grid_red, **GRID_ADABOOST}

        # =====================================================
        # 3. INNER CV + FIT
        # =====================================================

        inner_cv = GroupKFold(n_splits=3)

        search = GridSearchCV(
            pipeline,
            param_grid,
            cv=inner_cv,
            scoring=scoring,
            n_jobs=-1
        )

        search.fit(X_train_val, y_train_val, groups=groups_train_val)

        mejor_pipeline = search.best_estimator_
        params_limpios = {k.split('__')[1]: v for k, v in search.best_params_.items()}

        # =====================================================
        # 4. PREDICCIÓN
        # =====================================================

        y_pred = mejor_pipeline.predict(X_test)

        # =====================================================
        # 5. MÉTRICAS + PRINT
        # =====================================================

        acc_fold = accuracy_score(y_test, y_pred)
        f1_fold  = f1_score(y_test, y_pred, average=average, zero_division=0)

        accuracies.append(acc_fold)
        precisions.append(precision_score(y_test, y_pred, average=average, zero_division=0))
        recalls.append(recall_score(y_test, y_pred, average=average, zero_division=0))
        f1_scores.append(f1_fold)

        print(
            f"[Iter {fold}] Test Sujeto {sujeto_eval} -> "
            f"Params: {params_limpios} | "
            f"Acc: {acc_fold*100:.2f}% | "
            f"F1: {f1_fold*100:.2f}% | "
            f"Tiempo: {time.time() - start_time_fold:.2f} s"
        )

        fold += 1

    # =========================================================
    # RESULTADOS FINALES
    # =========================================================

    print(f"\n==========================================")
    print(f"Tiempo total LOSO Anidado: {(time.time() - start_time_total) / 60:.2f} min")
    print(f"ACCURACY FINAL : {np.mean(accuracies) * 100:.2f}% (± {np.std(accuracies) * 100:.2f}%)")
    print(f"PRECISION FINAL: {np.mean(precisions) * 100:.2f}%")
    print(f"RECALL FINAL   : {np.mean(recalls) * 100:.2f}%")
    print(f"F1-SCORE FINAL : {np.mean(f1_scores) * 100:.2f}%")

    return {
        "accuracy":  np.mean(accuracies),
        "precision": np.mean(precisions),
        "recall":    np.mean(recalls),
        "f1_score":  np.mean(f1_scores),
    }

# %%
resultados_pca = nested_loso_adaboost(
    datos=df_final_features,
    nombre_reduccion='pca'
)
# Out:
# --- NESTED LOSO | Modelo: ADABOOST | Reducción: PCA ---
# [Iter 1] Test Sujeto 1 -> Params: {'learning_rate': 1.0, 'n_estimators': 100} | Acc: 47.47% | F1: 43.36% | Tiempo: 471.47 s
# [Iter 2] Test Sujeto 2 -> Params: {'learning_rate': 2.0, 'n_estimators': 100} | Acc: 52.79% | F1: 50.94% | Tiempo: 465.91 s
# [Iter 3] Test Sujeto 3 -> Params: {'learning_rate': 2.0, 'n_estimators': 100} | Acc: 51.42% | F1: 44.87% | Tiempo: 450.91 s
# [Iter 4] Test Sujeto 4 -> Params: {'learning_rate': 1.0, 'n_estimators': 100} | Acc: 44.37% | F1: 36.03% | Tiempo: 472.71 s
# [Iter 5] Test Sujeto 5 -> Params: {'learning_rate': 2.0, 'n_estimators': 100} | Acc: 58.53% | F1: 49.83% | Tiempo: 477.03 s
# [Iter 6] Test Sujeto 6 -> Params: {'learning_rate': 2.0, 'n_estimators': 100} | Acc: 48.21% | F1: 42.23% | Tiempo: 474.37 s
# [Iter 7] Test Sujeto 7 -> Params: {'learning_rate': 2.0, 'n_estimators': 100} | Acc: 69.68% | F1: 63.35% | Tiempo: 466.69 s
# [Iter 8] Test Sujeto 8 -> Params: {'learning_rate': 2.0, 'n_estimators': 100} | Acc: 48.79% | F1: 46.39% | Tiempo: 462.68 s
#
# ==========================================
# Tiempo total LOSO Anidado: 62.36 min
# ACCURACY FINAL : 52.66% (± 7.55%)
# PRECISION FINAL: 52.52%
# RECALL FINAL   : 52.66%
# F1-SCORE FINAL : 47.12%

# %%
import numpy as np
import time
from tempfile import mkdtemp
from shutil import rmtree

from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import LeaveOneGroupOut, GroupKFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA, PCA
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# =========================================================
# GRID KPCA
# =========================================================

GRID_KPCA_NB = [
    {
        'reduccion__kernel': ['poly'],
        'reduccion__n_components': [32, 64],
        'reduccion__degree': [2, 3],
        'reduccion__gamma': [None]
    }
]

# =========================================================
# LOSO — NAIVE BAYES (Optimizado)
# =========================================================

def loso_naive_bayes(
    datos,
    nombre_reduccion,          # 'pca' | 'kpca' | 'bosque' | 'sin'
    target_col="activity",
    group_col="subject",
    average="weighted",
    random_state=42
):
    print(f"--- LOSO | Modelo: NAIVE BAYES | Reducción: {nombre_reduccion.upper()} ---")

    X = datos.drop(columns=[target_col, group_col])
    y = datos[target_col]
    groups = datos[group_col]

    logo = LeaveOneGroupOut()
    fold = 1

    accuracies, precisions, recalls, f1_scores = [], [], [], []
    start_time_total = time.time()

    # 1. Crear el directorio temporal para la caché del Pipeline
    cachedir = mkdtemp()

    try:
        for train_index, test_index in logo.split(X, y, groups):
            start_time_fold = time.time()

            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]
            groups_train    = groups.iloc[train_index]
            sujeto_eval     = groups.iloc[test_index].unique()[0]

            # =====================================================
            # PIPELINE SEGÚN REDUCCIÓN
            # =====================================================

            pasos = [('scaler', StandardScaler())]

            if nombre_reduccion == 'pca':
                pasos.append(('reduccion', PCA(n_components=0.95, random_state=random_state)))

            elif nombre_reduccion == 'kpca':
                # 2. Se añade eigen_solver='randomized' para cálculo rápido
                pasos.append(('reduccion', KernelPCA(random_state=random_state, n_jobs=-1, eigen_solver='randomized')))

            elif nombre_reduccion == 'bosque':
                selector = RandomForestClassifier(n_estimators=100, random_state=random_state, n_jobs=-1)
                pasos.append(('reduccion', SelectFromModel(selector)))

            elif nombre_reduccion == 'sin':
                pass

            else:
                raise ValueError(f"Reducción '{nombre_reduccion}' no implementada.")

            pasos.append(('modelo', GaussianNB()))

            # 3. Se asigna la memoria caché al Pipeline
            pipeline = Pipeline(pasos, memory=cachedir)

            # =====================================================
            # FIT: KPCA con GridSearch, resto directo
            # =====================================================

            if nombre_reduccion == 'kpca':
                inner_cv = GroupKFold(n_splits=3)

                search = GridSearchCV(
                    pipeline,
                    GRID_KPCA_NB,
                    cv=inner_cv,
                    scoring='accuracy',
                    n_jobs=-1
                )

                search.fit(X_train, y_train, groups=groups_train)

                mejor_pipeline = search.best_estimator_
                params_limpios = {k.split('__')[1]: v for k, v in search.best_params_.items()}

            else:
                pipeline.fit(X_train, y_train)
                mejor_pipeline = pipeline
                params_limpios = None

            # =====================================================
            # PREDICCIÓN
            # =====================================================

            y_pred = mejor_pipeline.predict(X_test)

            # =====================================================
            # MÉTRICAS + PRINT
            # =====================================================

            acc_fold = accuracy_score(y_test, y_pred)
            f1_fold  = f1_score(y_test, y_pred, average=average, zero_division=0)

            accuracies.append(acc_fold)
            precisions.append(precision_score(y_test, y_pred, average=average, zero_division=0))
            recalls.append(recall_score(y_test, y_pred, average=average, zero_division=0))
            f1_scores.append(f1_fold)

            params_str = f"Params: {params_limpios} | " if params_limpios else ""
            print(
                f"[Iter {fold}] Test Sujeto {sujeto_eval} -> "
                f"{params_str}"
                f"Acc: {acc_fold*100:.2f}% | "
                f"F1: {f1_fold*100:.2f}% | "
                f"Tiempo: {time.time() - start_time_fold:.2f} s"
            )

            fold += 1

    finally:
        # 4. Limpieza garantizada de archivos temporales
        rmtree(cachedir)

    # =========================================================
    # RESULTADOS FINALES
    # =========================================================

    print(f"\n==========================================")
    print(f"Tiempo total LOSO: {(time.time() - start_time_total) / 60:.2f} min")
    print(f"ACCURACY FINAL : {np.mean(accuracies) * 100:.2f}% (± {np.std(accuracies) * 100:.2f}%)")
    print(f"PRECISION FINAL: {np.mean(precisions) * 100:.2f}%")
    print(f"RECALL FINAL   : {np.mean(recalls) * 100:.2f}%")
    print(f"F1-SCORE FINAL : {np.mean(f1_scores) * 100:.2f}%")

    return {
        "accuracy":  np.mean(accuracies),
        "precision": np.mean(precisions),
        "recall":    np.mean(recalls),
        "f1_score":  np.mean(f1_scores),
    }

# %%
resultados_nb_pca = loso_naive_bayes(
    datos=df_final_features,
    nombre_reduccion='pca'
)
# Out:
# --- LOSO | Modelo: NAIVE BAYES | Reducción: PCA ---
# [Iter 1] Test Sujeto 1 -> Acc: 86.05% | F1: 85.71% | Tiempo: 1.01 s
# [Iter 2] Test Sujeto 2 -> Acc: 90.42% | F1: 90.23% | Tiempo: 0.84 s
# [Iter 3] Test Sujeto 3 -> Acc: 88.32% | F1: 88.65% | Tiempo: 0.62 s
# [Iter 4] Test Sujeto 4 -> Acc: 78.63% | F1: 75.17% | Tiempo: 0.55 s
# [Iter 5] Test Sujeto 5 -> Acc: 83.05% | F1: 79.57% | Tiempo: 0.45 s
# [Iter 6] Test Sujeto 6 -> Acc: 93.53% | F1: 93.55% | Tiempo: 0.41 s
# [Iter 7] Test Sujeto 7 -> Acc: 80.37% | F1: 78.89% | Tiempo: 0.75 s
# [Iter 8] Test Sujeto 8 -> Acc: 81.21% | F1: 78.52% | Tiempo: 1.03 s
#
# ==========================================
# Tiempo total LOSO: 0.10 min
# ACCURACY FINAL : 85.20% (± 4.92%)
# PRECISION FINAL: 86.75%
# RECALL FINAL   : 85.20%
# F1-SCORE FINAL : 83.79%

# %%
resultados_nb_pca = loso_naive_bayes(
    datos=df_final_features,
    nombre_reduccion='bosque'
)
# Out:
# --- LOSO | Modelo: NAIVE BAYES | Reducción: BOSQUE ---
# [Iter 1] Test Sujeto 1 -> Acc: 95.89% | F1: 95.88% | Tiempo: 29.33 s
# [Iter 2] Test Sujeto 2 -> Acc: 91.68% | F1: 90.92% | Tiempo: 21.72 s
# [Iter 3] Test Sujeto 3 -> Acc: 88.21% | F1: 86.37% | Tiempo: 23.24 s
# [Iter 4] Test Sujeto 4 -> Acc: 80.47% | F1: 76.15% | Tiempo: 24.00 s
# [Iter 5] Test Sujeto 5 -> Acc: 90.63% | F1: 89.77% | Tiempo: 21.76 s
# [Iter 6] Test Sujeto 6 -> Acc: 94.37% | F1: 94.27% | Tiempo: 23.06 s
# [Iter 7] Test Sujeto 7 -> Acc: 88.26% | F1: 87.49% | Tiempo: 22.17 s
# [Iter 8] Test Sujeto 8 -> Acc: 61.37% | F1: 53.73% | Tiempo: 21.99 s
#
# ==========================================
# Tiempo total LOSO: 3.12 min
# ACCURACY FINAL : 86.36% (± 10.42%)
# PRECISION FINAL: 86.15%
# RECALL FINAL   : 86.36%
# F1-SCORE FINAL : 84.32%

# %%
resultados_nb_pca = loso_naive_bayes(
    datos=df_final_features,
    nombre_reduccion='sin'
)
# Out:
# --- LOSO | Modelo: NAIVE BAYES | Reducción: SIN ---
# [Iter 1] Test Sujeto 1 -> Acc: 94.58% | F1: 94.58% | Tiempo: 0.18 s
# [Iter 2] Test Sujeto 2 -> Acc: 94.79% | F1: 94.73% | Tiempo: 0.19 s
# [Iter 3] Test Sujeto 3 -> Acc: 86.47% | F1: 85.15% | Tiempo: 0.18 s
# [Iter 4] Test Sujeto 4 -> Acc: 82.16% | F1: 78.42% | Tiempo: 0.17 s
# [Iter 5] Test Sujeto 5 -> Acc: 93.21% | F1: 92.98% | Tiempo: 0.18 s
# [Iter 6] Test Sujeto 6 -> Acc: 94.68% | F1: 94.57% | Tiempo: 0.17 s
# [Iter 7] Test Sujeto 7 -> Acc: 87.84% | F1: 87.05% | Tiempo: 0.19 s
# [Iter 8] Test Sujeto 8 -> Acc: 59.63% | F1: 52.81% | Tiempo: 0.19 s
#
# ==========================================
# Tiempo total LOSO: 0.02 min
# ACCURACY FINAL : 86.67% (± 11.11%)
# PRECISION FINAL: 86.11%
# RECALL FINAL   : 86.67%
# F1-SCORE FINAL : 85.04%

# %%
resultados_nb_pca = loso_naive_bayes(
    datos=df_final_features,
    nombre_reduccion='kpca'
)
# Out:
# --- LOSO | Modelo: NAIVE BAYES | Reducción: KPCA ---
# [Iter 1] Test Sujeto 1 -> Params: {'degree': 2, 'gamma': None, 'kernel': 'poly', 'n_components': 32} | Acc: 92.11% | F1: 92.02% | Tiempo: 190.29 s
# [Iter 2] Test Sujeto 2 -> Params: {'degree': 2, 'gamma': None, 'kernel': 'poly', 'n_components': 64} | Acc: 89.11% | F1: 88.17% | Tiempo: 159.73 s
# [Iter 3] Test Sujeto 3 -> Params: {'degree': 2, 'gamma': None, 'kernel': 'poly', 'n_components': 64} | Acc: 88.74% | F1: 87.36% | Tiempo: 141.96 s
# [Iter 4] Test Sujeto 4 -> Params: {'degree': 2, 'gamma': None, 'kernel': 'poly', 'n_components': 32} | Acc: 88.79% | F1: 88.04% | Tiempo: 135.93 s
# [Iter 5] Test Sujeto 5 -> Params: {'degree': 2, 'gamma': None, 'kernel': 'poly', 'n_components': 64} | Acc: 90.26% | F1: 88.20% | Tiempo: 165.39 s
# [Iter 6] Test Sujeto 6 -> Params: {'degree': 2, 'gamma': None, 'kernel': 'poly', 'n_components': 32} | Acc: 89.21% | F1: 88.62% | Tiempo: 135.54 s
# [Iter 7] Test Sujeto 7 -> Params: {'degree': 2, 'gamma': None, 'kernel': 'poly', 'n_components': 32} | Acc: 85.47% | F1: 84.86% | Tiempo: 137.99 s
# [Iter 8] Test Sujeto 8 -> Params: {'degree': 2, 'gamma': None, 'kernel': 'poly', 'n_components': 32} | Acc: 79.63% | F1: 77.11% | Tiempo: 154.05 s
#
# ==========================================
# Tiempo total LOSO: 20.35 min
# ACCURACY FINAL : 87.91% (± 3.57%)
# PRECISION FINAL: 89.55%
# RECALL FINAL   : 87.91%
# F1-SCORE FINAL : 86.80%
